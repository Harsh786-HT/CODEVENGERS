# %%
y_pred = model.predict(X_test)

r2   = r2_score(y_test, y_pred)
mae  = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print("\n" + "═"*60)
print(" MODEL PERFORMANCE SUMMARY ".center(60, "═"))
print(f"  R² score                  : {r2:>12.5f}")
print(f"  Mean Absolute Error       : {mae:>12.2f} kg CO₂")
print(f"  Root Mean Squared Error   : {rmse:>12.2f} kg CO₂")
print(f"  Mean Absolute % Error     : {mape:>11.2f}%")
print(f"  Mean actual emission      : {y_test.mean():>12.1f} kg CO₂")
print("═"*60)

# Feature importance
importances = pd.Series(model.feature_importances_, index=features)\
                 .sort_values(ascending=False)\
                 .round(4)

print("\nFeature Importances:")
print(importances)
