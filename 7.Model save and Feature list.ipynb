# %%
model_filename = "carbon_model_with_fuel.pkl" if INCLUDE_FUEL else "carbon_model_no_fuel.pkl"
joblib.dump(model, model_filename)

pd.Series(features).to_csv("model_features.csv", index=False, header=False)

print(f"\nModel saved → {model_filename}")
print("Features saved → model_features.csv")
